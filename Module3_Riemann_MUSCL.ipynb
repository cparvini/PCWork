# %%
# %matplotlib inline
import numpy
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.size'] = 16
from matplotlib import animation
from JSAnimation.IPython_display import display_animation
from traffic import rho_red_light, computeF

# %%
def get_vars(u):
    
    vel = u[1,:,:]/u[0,:,:]
    pres = (gamma - 1)*(u[2,:,:] - .5 * u[1,:,:]**2 / u[0,:,:])
    rho = u[0,:,:]
    
    return vel, pres, rho

def build_u(ICL,ICR,nx):
    
    u = numpy.zeros((3,nx))
    
    u[0,:nx/2] = ICL[0]
    u[1,:nx/2] = ICL[1]*ICL[0]
    u[2,:nx/2] = 0.5*ICL[1]**2/ICL[0]+ICL[2]/(gamma-1)
    
    u[0,nx/2:] = ICR[0]
    u[1,nx/2:] = ICR[1]*ICR[0]
    u[2,nx/2:] = 0.5*ICR[1]**2/ICR[0]+ICR[2]/(gamma-1)
    
    return u

def compute_F(u):
    
    u1, u2, u3 = u[0], u[1], u[2]
    f = numpy.array([u2,\
                  u2**2/u1+(gamma-1)*(u3-u2**2/(2*u1)),\
                  u2/u1*(u3+(gamma-1)*(u3-u2**2/(2*u1)))])
    return f

def ICs():

    ICL = numpy.zeros((3,1))
    ICR = numpy.zeros_like(ICL)
    
    ICL[0] = 1. 
    ICL[1] = 0.
    ICL[2] = 100.
    
    ICR[0] = .125
    ICR[1] = 0.
    ICR[2] = 10.
    
    return (ICL,ICR)

# %%
def rho_green_light(nx, rho_max, rho_light):
    """Computes "green light" initial condition with shock, and linear distribution behind

    Parameters
    ----------
    nx        : int
        Number of grid points in x
    rho_max   : float
        Maximum allowed car density
    rho_light : float
        Density of cars at stoplight

    Returns
    -------
    rho: array of floats
        Array with initial values of density
    """    
    rho = numpy.arange(nx)*2./nx*rho_light  # Before stoplight
    rho[(nx-1)/2:] = 0
    
    return rho

# %%
def animate(frame):
    x = numpy.arange(0,nx)
    x = (x-nx/2)*dx
    y = varview[:,frame]
    line.set_data(x,y)
    return line,
    
#def animate(data):
#    x = numpy.linspace(0,4,nx)
#    y = data
#    line.set_data(x,y)
#    return line,

# %%
def godunov(rho, nt, dt, dx, rho_max, V_max):
    """ Computes the solution with the Godunov scheme using the Lax-Friedrichs flux.
    
    Parameters
    ----------
    rho    : array of floats
            Density at current time-step
    nt     : int
            Number of time steps
    dt     : float
            Time-step size
    dx     : float
            Mesh spacing
    rho_max: float
            Maximum allowed car density
    V_max  : float
            Speed limit
    
    Returns
    -------
    rho_n : array of floats
            Density after nt time steps at every point x
    """
    
    #initialize our results array with dimensions nt by nx
    rho_n = numpy.zeros((nt,len(rho)))      
    #copy the initial u array into each row of our new array
    rho_n[:,:] = rho.copy()              
    
    #setup some temporary arrays
    rho_plus = numpy.zeros_like(rho)
    rho_minus = numpy.zeros_like(rho)
    flux = numpy.zeros_like(rho)
  
    for t in range(1,nt):
        
        rho_plus[:-1] = rho[1:] # Can't do i+1/2 indices, so cell boundary
        rho_minus[:] = rho[:] # arrays at index i are at location i+1/2
        flux = 0.5 * (computeF(V_max, rho_max, rho_minus) + 
                      computeF(V_max, rho_max, rho_plus) + 
                      dx / dt * (rho_minus - rho_plus))
        rho_n[t,1:-1] = rho[1:-1] + dt/dx*(flux[:-2]-flux[1:-1])
        rho_n[t,0] = rho[0]
        rho_n[t,-1] = rho[-1]
        rho = rho_n[t].copy()
        
    return rho_n

# %%
def minmod(e, dx, nx):
    """
    Compute the minmod approximation to the slope
    
    Parameters
    ----------
    e  : array of float 
        input data
    dx : float 
        spacestep
    nx : int
        number of spacial steps
    
    Returns
    -------
    sigma : array of float 
            minmod slope
    """
    
    sigma = numpy.zeros_like(e)
    de_minus = numpy.ones_like(e)
    de_plus = numpy.ones_like(e)
    
    de_minus[:,1:] = e[:,1:] - e[:,:-1]
    de_plus[:,:-1] = e[:,:-1] - e[:,1:]
    # The following is inefficient but easy to read
    for j in range(1,3):
        for i in range(1, nx-1):
            if (de_minus[j,i] * de_plus[j,i] < 0.0):
                sigma[j,i] = 0.0
            elif (numpy.abs(de_minus[j,i]) < numpy.abs(de_plus[j,i])):
                sigma[j,i] = de_minus[j,i]
            else:
                sigma[j,i] = de_plus[j,i]
    return sigma

# %%
def muscl(uf, nt, dt, dx, nx):
    """ Computes the solution with the MUSCL scheme using the Lax-Friedrichs flux,
    RK2 in time and minmod slope limiting.
    
    Parameters
    ----------
    uf     : array of floats
            Array u at current time-step
    nt     : int
            Number of time steps
    dt     : float
            Time-step size
    dx     : float
            Mesh spacing
    nx     : int
            Number of spacial steps
    
    Returns
    -------
    un : array of floats
            Array u after nt time steps at every point x
    """
    
    #initialize our results array with dimensions 3 by nx by nt
    un = numpy.zeros((3,nx,nt))      
    #copy the initial u array into each row of our new array
    un[:,:,0] = uf.copy()              
    
    #setup some temporary arrays
    un_plus = numpy.zeros_like(uf)
    un_minus = numpy.zeros_like(uf)
    flux = numpy.zeros_like(uf)
    un_star = numpy.zeros_like(uf)

    for t in range(1,nt):
               
        sigma = minmod(uf,dx,nx) #calculate minmod slope

        #reconstruct values at cell boundaries
        un_plus[:,:-1] = uf[:,1:] + sigma[:,1:]*dx/2.
        un_minus = uf - sigma*dx/2.
        
        flux = 0.5 * (compute_F(un_minus) + 
                      compute_F(un_plus) + 
                      dx / dt * (un_minus - un_plus))
        
        un_star[:,1:-1] = uf[:,1:-1] + dt/dx*(flux[:,:-2]-flux[:,1:-1])
        un_star[:,0] = uf[:,0]
        un_star[:,-1] = uf[:,-1]
        
        
        sigma = minmod(un_star,dx,nx) #calculate minmod slope
    
        #reconstruct values at cell boundaries
        un_plus[:,:-1] = un_star[:,1:] + sigma[:,1:]*dx/2.
        un_minus = un_star - sigma*dx/2.
        
        
        flux = 0.5 * (compute_F(un_minus) + 
                      compute_F(un_plus) + 
                      dx / dt * (un_minus - un_plus))
        
        un[:,1:-1,t] = 0.5 * (uf[:,1:-1] + un_star[:,1:-1] + 
                               dt/dx*(flux[:,:-2]-flux[:,1:-1]))
        un[:,0,t] = uf[:,0]
        un[:,-1,t] = uf[:,-1]
        uf = un[:,:,t].copy()
        
    return un

# %% [markdown]
# #Basic initial condition parameters
# #defining grid size, time steps, CFL condition, etc...
# nx = 81
# nt = 30
# dx = 4.0/nx
#
# rho_in = 5.
# rho_max = 10.
# V_max = 1.0
# x = numpy.linspace(0,4,nx)
#
# #make sure that u is set to our expected initial conditions
# rho = rho_red_light(nx, rho_max, rho_in)
# #rho = rho_green_light(nx, rho_max, rho_in)
# rho_n = muscl(rho, nt, dt, dx, rho_max, V_max)
#
# fig = plt.figure();
# ax = plt.axes(xlim=(0,4),ylim=(0.75*rho_in,1.25*rho_max),xlabel=('Distance'),ylabel=('Traffic density'));
# line, = ax.plot([],[],color='#003366', lw=2);
#
# anim = animation.FuncAnimation(fig, animate, frames=rho_n, interval=50)
# display_animation(anim, default_mode='loop')

# %%
nx = 81
nt = 61
dx = 20./(nx-1)
gamma = 1.4

sigma = .08
dt = sigma*dx

ICL,ICR = ICs()
uf = build_u(ICL,ICR,nx)
ut = muscl(uf,nt,dt,dx,nx)
vel,pres,rho = get_vars(ut)

varview = vel.copy()
fig = plt.figure();
ax = plt.axes(xlim=(-nx/2*dx,nx/2*dx),ylim=(0,numpy.amax(varview)*1.5));
line, = ax.plot([],[],lw=2);
anim = animation.FuncAnimation(fig, animate, nt, interval=50)
display_animation(anim, default_mode='loop')
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgVLNRMDPQDRPGJUUZ">
#     <br>
#     <input id="_anim_sliderVLNRMDPQDRPGJUUZ" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animVLNRMDPQDRPGJUUZ.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animVLNRMDPQDRPGJUUZ.slower()">&#8211;</button>
#     <button onclick="animVLNRMDPQDRPGJUUZ.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animVLNRMDPQDRPGJUUZ.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animVLNRMDPQDRPGJUUZ.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animVLNRMDPQDRPGJUUZ.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animVLNRMDPQDRPGJUUZ.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animVLNRMDPQDRPGJUUZ.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animVLNRMDPQDRPGJUUZ.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animVLNRMDPQDRPGJUUZ.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectVLNRMDPQDRPGJUUZ" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgVLNRMDPQDRPGJUUZ";
#     var slider_id = "_anim_sliderVLNRMDPQDRPGJUUZ";
#     var loop_select_id = "_anim_loop_selectVLNRMDPQDRPGJUUZ";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %%
fig = plt.figure(figsize=(10,8));

ax1 = plt.subplot(311)
ax2 = plt.subplot(312)
ax3 = plt.subplot(313)

ax1.set_xlim(-nx/2*dx,nx/2*dx)
ax1.set_ylim(0,numpy.amax(vel)*1.5)
ax2.set_xlim(-nx/2*dx,nx/2*dx)
ax2.set_ylim(0,numpy.amax(pres)*1.5)
ax3.set_xlim(-nx/2*dx,nx/2*dx)
ax3.set_ylim(0,numpy.amax(rho)*1.5)

ax1.set_ylabel("Velocity")
ax2.set_ylabel("Pressure")
ax3.set_xlabel("X Location (m)")
ax3.set_ylabel("Density")

N = 3
lines = [plt.plot([], [])[0] for _ in range(N)]

def init3():    
    for line in lines:
        line.set_data([], [])
    return lines

def animate3(i):
    x = numpy.arange(0,nx)
    x = (x-nx/2)*dx
    y = numpy.array((vel[:,i],pres[:,i],rho[:,i]))
    for j,line in enumerate(lines):
        line.set_data( x, y[j,:] )
    return lines

anim1 = animation.FuncAnimation(fig, animate3, nt, init_func = init3, \
                               interval=50, blit=True)
display_animation(anim1, default_mode='loop')
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgCTZAMOFZVRZDPYKU">
#     <br>
#     <input id="_anim_sliderCTZAMOFZVRZDPYKU" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animCTZAMOFZVRZDPYKU.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animCTZAMOFZVRZDPYKU.slower()">&#8211;</button>
#     <button onclick="animCTZAMOFZVRZDPYKU.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animCTZAMOFZVRZDPYKU.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animCTZAMOFZVRZDPYKU.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animCTZAMOFZVRZDPYKU.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animCTZAMOFZVRZDPYKU.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animCTZAMOFZVRZDPYKU.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animCTZAMOFZVRZDPYKU.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animCTZAMOFZVRZDPYKU.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectCTZAMOFZVRZDPYKU" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgCTZAMOFZVRZDPYKU";
#     var slider_id = "_anim_sliderCTZAMOFZVRZDPYKU";
#     var loop_select_id = "_anim_loop_selectCTZAMOFZVRZDPYKU";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6
